# %%
# !faust -A fraud_detection_worker worker -l info
# Out:
# (0l(BƒaµS† v1.10.4(0wqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqk(B
# (0x(B id          (0x(B fraud_detection_app                           (0x(B
# (0x(B transport   (0x(B [URL('kafka://kafka:9092')]                   (0x(B
# (0x(B store       (0x(B memory:                                       (0x(B
# (0x(B web         (0x(B http://localhost:6066/                        (0x(B
# (0x(B log         (0x(B -stderr- (info)                               (0x(B
# (0x(B pid         (0x(B 2276                                          (0x(B
# (0x(B hostname    (0x(B 82218dd690e1                                  (0x(B
# (0x(B platform    (0x(B CPython 3.9.10 (Linux x86_64)                 (0x(B
# (0x(B drivers     (0x(B                                               (0x(B
# (0x(B   transport (0x(B aiokafka=1.1.6                                (0x(B
# (0x(B   web       (0x(B aiohttp=3.8.1                                 (0x(B
# ...
